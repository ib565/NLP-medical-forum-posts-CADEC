# %% [markdown]
# ## Adverse Drug Event Extraction Using Generative NLP Models (CADEC Dataset)
#
# An NLP system that extracts adverse drug events (ADEs) from CADEC patient forum texts using generative models from Hugging Face.

# %% [markdown]
# ## Setup and Initialization

# %% [markdown]
# ### Mount drive and load dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp /content/drive/MyDrive/Datasets/CADEC.v2.zip /content/
# !unzip -q CADEC.v2.zip -d CADEC.v2
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# replace CADEC.v2/cadec/meddra/ARTHROTEC.1.ann? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %% [markdown]
# ### Install Required Packages

# %%
# %%capture
# %pip install langchain transformers langchain-huggingface bitsandbytes accelerate rapidfuzz

# %% [markdown]
# ### Import Libraries and Define Constants

# %%
from transformers import pipeline
from rapidfuzz import fuzz, process
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from concurrent.futures import ThreadPoolExecutor, as_completed
from functools import lru_cache
import json
import requests
import torch
import re
import os

MAX_RETRIES = 3
BATCH_SIZE = 20
SAMPLE_SIZE = 400
GENERATIVE_MODEL_NAME = "unsloth/Phi-4-mini-instruct-unsloth-bnb-4bit"
EMBEDDING_MODEL_NAME = "paraphrase-MiniLM-L6-v2"
UMLS_API_KEY = "xxxxxxxxxx-xxxx-xxxx-xxxx-xxxxxxxxxxxx"
UMLS_URL = "https://uts-ws.nlm.nih.gov/rest/search/current"



print(f"CUDA available: {torch.cuda.is_available()}")
print(
    f"Current CUDA device: {torch.cuda.current_device() if torch.cuda.is_available() else 'None'}"
)
# Out:
# CUDA available: True
# Current CUDA device: 0

# %% [markdown]
# ## Data Preprocessing

# %%
directory = "CADEC.v2/cadec"
text_dir = directory + "/text"
original_ann_dir = directory + "/original"

# %% [markdown]
# ### Load posts

# %%
def load_posts(directory):
    """
    Load posts from text files in the specified directory.
    Args:
        directory (str): Directory path containing post text files
    Returns:
        list: List of dictionaries with file name and post content
    """
    posts = []
    for filename in sorted(os.listdir(directory)):
        if filename.endswith(".txt"):
            filepath = os.path.join(directory, filename)
            with open(filepath, "r", encoding="utf-8") as file:
                text = file.read()
                posts.append({"file_name": filename, "content": text})
    return posts


posts = load_posts(text_dir)
print(f"Loaded {len(posts)} posts")
posts[:2]
# Out:
# Loaded 1250 posts
# [{'file_name': 'ARTHROTEC.1.txt',
#   'content': "I feel a bit drowsy & have a little blurred vision, so far no gastric problems.\nI've been on Arthrotec 50 for over 10 years on and off, only taking it when I needed it.\nDue to my arthritis getting progressively worse, to the point where I am in tears with the agony, gp's started me on 75 twice a day and I have to take it.\nevery day for the next month to see how I get on, here goes.\nSo far its been very good, pains almost gone, but I feel a bit weird, didn't have that when on 50.\n"},
#  {'file_name': 'ARTHROTEC.10.txt',
#   'content': 'Hunger pangs.\nBrilliant, I have a new lease of life, i walk up & down steps properly, no longer sideways like a toddler, hip pain as gone other than if i jar it.\n'}]

# %% [markdown]
# ### Load annotations

# %%
def load_annotations(directory):
    """
    Load annotations from .ann files in the specified directory.
    Args:
        directory (str): Directory path containing annotation files
    Returns:
        list: List of dictionaries with file name and annotations
    """
    annotated_posts = []
    for filename in sorted(os.listdir(directory)):
        if filename.endswith(".ann"):
            filepath = os.path.join(directory, filename)
            post_annotations = {
                "file_name": filename,
                "drugs": [],
                "ades": [],
                "symptoms_diseases": [],
            }
            valid_file = False
            try:
                with open(filepath, "r", encoding="utf-8") as file:
                    for line in file:
                        line = line.strip()
                        if not line or line.startswith("#") or line.startswith("---"):
                            continue
                        parts = line.split("\t")
                        if len(parts) != 3:
                            continue
                        valid_file = True
                        ann_id, ann_info, text = parts[0], parts[1], parts[2]
                        info_fields = ann_info.split()
                        if not info_fields:
                            continue
                        ann_type = info_fields[0].strip().lower()
                        if ann_type == "drug":
                            post_annotations["drugs"].append(text.strip())
                        elif ann_type == "adr":
                            post_annotations["ades"].append(text.strip())
                        elif ann_type in ("symptom", "disease", "finding"):
                            post_annotations["symptoms_diseases"].append(text.strip())
                        else:
                            continue
                    if not valid_file:
                        print(f"Warning: Empty file {filename}")
                    annotated_posts.append(post_annotations)
            except Exception as e:
                print(f"Warning: Could not process file {filename}. Error: {e}")
                annotated_posts.append(post_annotations)
    return annotated_posts


annotated_posts = load_annotations(original_ann_dir)
print(f"Loaded {len(annotated_posts)} annotated posts")
annotated_posts[:2]
# Out:
# Warning: Empty file CAMBIA.1.ann
# Warning: Empty file LIPITOR.197.ann
# Warning: Empty file LIPITOR.243.ann
# Warning: Empty file LIPITOR.28.ann
# Warning: Empty file LIPITOR.285.ann
# Warning: Empty file LIPITOR.299.ann
# Warning: Empty file LIPITOR.308.ann
# Warning: Empty file LIPITOR.313.ann
# Warning: Empty file LIPITOR.383.ann
# Warning: Empty file LIPITOR.4.ann
# Warning: Empty file LIPITOR.40.ann
# Warning: Empty file LIPITOR.41.ann
# Warning: Empty file LIPITOR.416.ann
# Warning: Empty file LIPITOR.437.ann
# Warning: Empty file LIPITOR.438.ann
# Warning: Empty file LIPITOR.444.ann
# Warning: Empty file LIPITOR.487.ann
# Warning: Empty file LIPITOR.489.ann
# Warning: Empty file LIPITOR.49.ann
# Warning: Empty file LIPITOR.5.ann
# Warning: Empty file LIPITOR.516.ann
# Warning: Empty file LIPITOR.528.ann
# Warning: Empty file LIPITOR.529.ann
# Warning: Empty file LIPITOR.549.ann
# Warning: Empty file LIPITOR.550.ann
# Warning: Empty file LIPITOR.560.ann
# Warning: Empty file LIPITOR.577.ann
# Warning: Empty file LIPITOR.600.ann
# Warning: Empty file LIPITOR.609.ann
# Warning: Empty file LIPITOR.62.ann
# Warning: Empty file LIPITOR.628.ann
# Warning: Empty file LIPITOR.636.ann
# Warning: Empty file LIPITOR.637.ann
# Warning: Empty file LIPITOR.664.ann
# Warning: Empty file LIPITOR.680.ann
# Warning: Empty file LIPITOR.696.ann
# Warning: Empty file LIPITOR.714.ann
# Warning: Empty file LIPITOR.741.ann
# Warning: Empty file LIPITOR.752.ann
# Warning: Empty file LIPITOR.768.ann
# Warning: Empty file LIPITOR.783.ann
# Warning: Empty file LIPITOR.791.ann
# Warning: Empty file LIPITOR.802.ann
# Warning: Empty file LIPITOR.813.ann
# Warning: Empty file LIPITOR.828.ann
# Warning: Empty file LIPITOR.864.ann
# Warning: Empty file LIPITOR.871.ann
# Warning: Empty file LIPITOR.880.ann
# Warning: Empty file LIPITOR.881.ann
# Warning: Empty file LIPITOR.895.ann
# Warning: Empty file LIPITOR.919.ann
# Warning: Empty file LIPITOR.938.ann
# Warning: Empty file LIPITOR.942.ann
# Warning: Empty file LIPITOR.960.ann
# Warning: Empty file LIPITOR.964.ann
# Warning: Empty file PENNSAID.2.ann
# Warning: Empty file SOLARAZE.1.ann
# Warning: Empty file SOLARAZE.3.ann
# Warning: Empty file VOLTAREN-XR.11.ann
# Warning: Empty file VOLTAREN-XR.13.ann
# Warning: Empty file VOLTAREN-XR.4.ann
# Warning: Empty file VOLTAREN-XR.6.ann
# Warning: Empty file VOLTAREN-XR.7.ann
# Warning: Empty file VOLTAREN-XR.9.ann
# Loaded 1250 annotated posts
# [{'file_name': 'ARTHROTEC.1.ann',
#   'drugs': ['Arthrotec'],
#   'ades': ['bit drowsy',
#    'little blurred vision',
#    'gastric problems',
#    'feel a bit weird'],
#   'symptoms_diseases': ['arthritis', 'agony', 'pains']},
#  {'file_name': 'ARTHROTEC.10.ann',
#   'drugs': [],
#   'ades': ['Hunger pangs'],
#   'symptoms_diseases': ['hip pain', 'walk up & down steps sideways']}]

# %% [markdown]
# ## Entity Extraction
#
# Using a generative model to expand abbreviations then extract entities from un-annotated posts.

# %% [markdown]
# ### Initialize pipeline and prompts

# %%
hf_pipe = pipeline(
    "text-generation", model=GENERATIVE_MODEL_NAME, batch_size=BATCH_SIZE, model_kwargs={"temperature": 0}
)

EXTRACTION_SYSTEM_PROMPT = """Analyze the provided medical forum post on patient-reported Adverse Drug Events. Extract all mentions of Drugs, Adverse Drug Events, and Symptoms/Diseases.
                Keys:
                - 'drugs': Exact mentions of the name of a medicine or drug. Ignore generic terms like "pills". Ignore dosage strength and form (e.g., "75", "tablet").
                - 'ades': Any adverse drug reactions or side effects implied to be due to a drug.
                - 'symptoms_diseases': Any other medical conditions or symptoms mentioned.

                Use empty lists for categories with no mentions. If an entity could be interpreted as either an ADE or a generic symptom/disease, classify it as an ADE. Do not give duplicates. Return a JSON object with keys 'drugs', 'ades', and 'symptoms_diseases', each mapping to a list of exact extracted strings. Ensure valid JSON with only the extracted terms, no explanations."""

EXPAND_ABB_SYSTEM_PROMPT = "Expand all medical abbreviations in the provided text, replacing each abbreviation with its full term. Return only the original text with these expansions, preserving all other content, structure, and wording unchanged. Do not add any explanation."
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:631: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:631: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Device set to use cuda:0

# %% [markdown]
# ### Abbreviation Expansion

# %%
def expand_abbreviations_batch(posts):
    """
    Expand medical abbreviations in a batch of posts using the language model.
    Args:
        posts (list): List of post dictionaries with 'content' field
    Returns:
        list: List of expanded post texts
    """
    messages = []
    for post in posts:
        messages.append(
            [
                {"role": "system", "content": EXPAND_ABB_SYSTEM_PROMPT},
                {"role": "user", "content": post["content"]},
            ]
        )
    output = hf_pipe(messages, max_new_tokens=512)
    expanded_posts = []
    for i in range(len(posts)):
        expanded_posts.append(
            output[i][0]["generated_text"][len(messages[0])]["content"]
        )
    return expanded_posts

# %% [markdown]
# ### Entity Extraction

# %%
def extract_entities_json(text, feedback=None, previous_attempt=None) -> str:
    """
    Extracts entities from `text` as a JSON string, optionally using feedback and a previous attempt.
    Args:
        text (str): The source text to extract entities from.
        feedback (str, optional): Feedback on the previous extraction output.
        previous_attempt (str, optional): JSON string output from a previous extraction attempt.
    Returns:
        str: raw json string of entities.
    """
    dialogue = [
        {"role": "system", "content": EXTRACTION_SYSTEM_PROMPT},
        {"role": "user", "content": text},
    ]
    if previous_attempt:
        dialogue.append({"role": "assistant", "content": previous_attempt})
    if feedback:
        dialogue.append(
            {
                "role": "user",
                "content": (
                    "I reviewed the previous extraction and have the following feedback:\n"
                    f"{feedback}\n"
                    "Please revise the extraction to address these points while adhering to the formatting instructions."
                ),
            }
        )
    messages = [dialogue]
    result = hf_pipe(messages, max_new_tokens=512)
    output = result[0][0]["generated_text"][len(dialogue)]["content"]
    return output


def extract_entities_batch(texts) -> list:
    """
    Extract entities from a batch of texts as JSON strings. Uses HF batch processing.
    Args:
        texts (list of str): The source texts to extract entities from.
    Returns:
        list of str: List of raw JSON strings of entities.
    """
    messages = []
    for text in texts:
        messages.append(
            [
                {"role": "system", "content": EXTRACTION_SYSTEM_PROMPT},
                {"role": "user", "content": text},
            ]
        )
    output = hf_pipe(messages, max_new_tokens=512)
    extracted_entites_json = []
    for i in range(len(texts)):
        extracted_entites_json.append(output[i][0]["generated_text"][len(messages[0])]["content"])
    return extracted_entites_json

# %% [markdown]
# ### Expand and extract entities, then save to files

# %%
expanded_texts = expand_abbreviations_batch(posts[:SAMPLE_SIZE])
raw_json_strings = extract_entities_batch(expanded_texts)

with open("expanded_texts.txt", "w") as outfile:
    for item in expanded_texts:
        outfile.write(item.strip() + "\n\n")


with open("raw_json_strings.jsonl", "w") as outfile:
    for item in raw_json_strings:
        outfile.write(item.strip() + "\n")

print(f"Processed {len(expanded_texts)} posts\n")
print(f"Sample expanded text: {expanded_texts[0][:200]}...\n")
print(f"Sample extracted entities: {raw_json_strings[0]}")
# Out:
# Processed 400 posts
#
# Sample expanded text: I feel a bit drowsy & have a little blurred vision, so far no gastric problems.
# I've been on Arthrotec 50 for over 10 years on and off, only taking it when I needed it.
# Due to my arthritis getting pro...
#
# Sample extracted entities: ```json
# {
#   "drugs": ["Arthrotec", "75"],
#   "ades": ["drowsy", "blurred vision", "weird feeling"],
#   "symptoms_diseases": ["arthritis", "agony"]
# }
# ```

# %% [markdown]
# ## Entity standardization using UMLS
#
# Using the UMLS API to standardize the extracted entities. Run and tested with API key.

# %%
vocab_map = {
    "drugs": "RXNORM",
    "ades": "SNOMEDCT_US",
    "symptoms_diseases": "SNOMEDCT_US",
}

@lru_cache(maxsize=1024)
def query_umls(entity: str, vocab: str) -> dict:
    """
    Query the UMLS API for standardized terms.
    Args:
        entity (str): The entity term to standardize
        vocab (str): The vocabulary to search in (e.g., "RXNORM", "SNOMEDCT_US")
    Returns:
        dict: Dictionary with original term, standardized term, and concept ID
    """
    params = {"string": entity, "apiKey": UMLS_API_KEY, "sabs": vocab, "pageSize": 1}

    try:
        response = requests.get(UMLS_URL, params=params, timeout=30)
        response.raise_for_status()
        results = response.json().get("result", {}).get("results", [])
        return {
            "original": entity,
            "standard_term": results[0]["name"] if results else None,
            "CUI": results[0]["ui"] if results else None,
        }
    except Exception as e:
        print(f"Error querying UMLS: {e}\nparams={params}")
        return {"original": entity, "standard_term": None, "CUI": None}


def standardize_entities(entities: dict) -> dict:
    """
    Standardize entities using UMLS.
    Args:
        entities (dict): keys: 'drugs', 'ades', 'symptoms_diseases'
    Returns:
        dict: standardized terms
    """
    try:
        return {
            key: [
                (query_umls(item, vocab).get("standard_term") or item)
                for item in entities.get(key, [])
            ]
            for key, vocab in vocab_map.items()
        }
    except Exception as e:
        print(f"Error standardizing entities: {e}\nInput: {entities}")
        return entities


def standardize_annotations_parallel(entities_list, max_workers=30):
    """
    Standardize multiple entity dictionaries in parallel.
    Args:
        entities_list (list): List of entity dictionaries
        max_workers (int): Maximum number of parallel workers
    Returns:
        list: List of standardized entity dictionaries
    """
    results = [
        {
        "file_name": post["file_name"],
        "entities": {cat: [] for cat in vocab_map}
        }
        for post in entities_list
    ]

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {
            executor.submit(query_umls, value, vocab_map[cat]): (i, cat, value)
            for i, post in enumerate(entities_list)
            for cat in vocab_map
            for value in post.get(cat, [])
        }
        for future in as_completed(futures):
            i, cat, original = futures[future]
            std_term = future.result().get("standard_term") or original
            results[i]["entities"][cat].append(std_term)

    return results

# %% [markdown]
# ### Run batched standardization

# %%
# Standardize ground truth annotated posts first
standardized_annotated_posts = standardize_annotations_parallel(annotated_posts[:SAMPLE_SIZE])
standardized_annotated_posts[:2]
# Out:
# [{'file_name': 'ARTHROTEC.1.ann',
#   'entities': {'drugs': ['Arthrotec'],
#    'ades': ['gastric problems',
#     'little blurred vision',
#     'feel a bit weird',
#     'bit drowsy'],
#    'symptoms_diseases': ['Agony', 'Arthritis', 'Growing pains']}},
#  {'file_name': 'ARTHROTEC.10.ann',
#   'entities': {'drugs': [],
#    'ades': ['Hunger pangs'],
#    'symptoms_diseases': ['walk up & down steps sideways', 'Hip joint pain']}}]

# %% [markdown]
# ## Verification system
# Verify the extracted entities by
# - parsing JSON
# - checking completeness
# - checking semantic similarity

# %%
embedding_model = SentenceTransformer(EMBEDDING_MODEL_NAME, device="cuda:0" if torch.cuda.is_available() else "cpu")

SISTER_CATEGORIES = {"ades": "symptoms_diseases", "symptoms_diseases": "ades"}


def parse_json_string(raw_str):
    """
    Parse a JSON string from a potentially messy text.
    Args:
        raw_str (str): Raw string containing JSON
    Returns:
        dict: Parsed JSON object
    """
    try:
        json_match = re.search(r"\{.*?\}", raw_str, re.DOTALL)
        if not json_match:
            raise json.JSONDecodeError("No JSON object found", raw_str, 0)
        json_str = json_match.group(0)
        return json.loads(json_str)
    except json.JSONDecodeError:
        raise
    except Exception as e:
        raise json.JSONDecodeError(f"Failed to extract JSON: {str(e)}", raw_str, 0)


def validate_and_count_entities(extracted_entities, ground_truth_entities):
    """
    Validate entity dictionaries and collect count information.
    Args:
        extracted_entities (dict): Dictionary of extracted entities
        ground_truth_entities (dict): Dictionary of ground truth entities
    Returns:
        tuple: (is_valid, error_message, gt_counts, gen_counts, total_gt, total_gen)
    """
    if not ground_truth_entities:
        return True, None, {}, {}, 0, 0

    gt_counts = {}
    gen_counts = {}
    total_gt = 0
    total_gen = 0

    for category in ground_truth_entities:
        gt_entities = ground_truth_entities[category]
        if not isinstance(gt_entities, list):
            continue
        if category not in extracted_entities:
            return False, f"Feedback: Missing category '{category}'.", {}, {}, 0, 0

        gen_entities = extracted_entities.get(category, [])

        gt_counts[category] = len(gt_entities)
        gen_counts[category] = len(gen_entities)

        total_gt += len(gt_entities)
        total_gen += len(gen_entities)

    return True, None, gt_counts, gen_counts, total_gt, total_gen


def generate_feedback(gt_counts, gen_counts, default_message):
    """
    Generate feedback message based on entity count differences.
    Args:
        gt_counts (dict): Ground truth entity counts by category
        gen_counts (dict): Generated entity counts by category
        default_message (str): Default message if no specific feedback
    Returns:
        str: Feedback message
    """
    feedback_parts = []

    for category in gt_counts:
        gt_count = gt_counts[category]
        gen_count = gen_counts.get(category, 0)

        if gt_count > gen_count:
            feedback_parts.append(
                f"more '{category}' (expected {gt_count}, got {gen_count})"
            )
        elif gt_count < gen_count:
            feedback_parts.append(
                f"fewer '{category}' (expected {gt_count}, got {gen_count})"
            )

    if not feedback_parts:
        return default_message

    return "Feedback: Try extracting " + ", ".join(feedback_parts) + "."


def verify_completeness(
    extracted_entities,
    ground_truth_entities,
    completeness_threshold=0.6,
    fuzzy_match_threshold=60,
    partial_credit = 0.7
):
    """
    Verify if extracted entities match ground truth using fuzzy string matching.
    Allows matches across sister categories with partial credit.
    Args:
        extracted_entities (dict): Dictionary of extracted entities
        ground_truth_entities (dict): Dictionary of ground truth entities
        completeness_threshold (float): Threshold for completeness ratio
        fuzzy_match_threshold (int): Threshold for fuzzy string matching
        partial_credit (float): Credit for matches in sister categories
    Returns:
        tuple: (is_verified, feedback_message)
    """
    is_valid, error, gt_counts, gen_counts, total_gt, total_gen = (
        validate_and_count_entities(extracted_entities, ground_truth_entities)
    )

    if not is_valid:
        return False, error

    total_match_credit = 0.0

    for category, gt_entities in ground_truth_entities.items():
        if not gt_entities:
            continue
        if not isinstance(gt_entities, list):
            continue
        gen_entities = extracted_entities.get(category, [])
        processed_gen_entities = [e.lower() for e in gen_entities]

        for gt_entity in gt_entities:
            match_credit = 0.0
            best_score = 0

            # Try matching in the same category
            if processed_gen_entities:
                _, score, _ = process.extractOne(
                    gt_entity.lower(), processed_gen_entities, scorer=fuzz.token_ratio
                )
                if score >= fuzzy_match_threshold:
                    best_score = score
                    match_credit = 1.0

            # If no match, try sister category
            if best_score < fuzzy_match_threshold and category in SISTER_CATEGORIES:
                sister_category = SISTER_CATEGORIES[category]
                sister_entities = extracted_entities.get(sister_category, [])

                if sister_entities:
                    processed_sister_entities = [e.lower() for e in sister_entities]
                    _, score, _ = process.extractOne(
                        gt_entity.lower(),
                        processed_sister_entities,
                        scorer=fuzz.token_ratio,
                    )
                    if score >= fuzzy_match_threshold:
                        match_credit = partial_credit

            total_match_credit += match_credit

    recall = total_match_credit / total_gt if total_gt > 0 else 1.0
    if recall >= completeness_threshold:
        return True, None

    return False, generate_feedback(
        gt_counts, gen_counts, "Feedback: Check entity accuracy or category assignment."
    )


def verify_similarity(
    extracted_entities,
    ground_truth_entities,
    similarity_threshold=0.7,
    match_threshold=0.6,
    partial_credit=0.7,
):
    """
    Verify if extracted entities are semantically similar to ground truth using embeddings.
    Allows matches across sister categories with partial credit.
    Args:
        extracted_entities (dict): Dictionary of extracted entities
        ground_truth_entities (dict): Dictionary of ground truth entities
        similarity_threshold (float): Threshold for semantic similarity
        match_threshold (float): Threshold for overall matching ratio
        partial_credit (float): Credit for matches in sister categories
    Returns:
        tuple: (is_verified, feedback_message)
    """
    is_valid, error, gt_counts, gen_counts, total_gt, total_gen = (
        validate_and_count_entities(extracted_entities, ground_truth_entities)
    )
    if not is_valid:
        return False, error

    gt_embeddings = {
        cat: embedding_model.encode(gt_list)
        for cat, gt_list in ground_truth_entities.items()
        if gt_list and isinstance(gt_list, list)
    }

    total_match_score = 0.0

    for cat, gt_list in ground_truth_entities.items():
        gen_list = extracted_entities.get(cat, [])

        if not gt_list and not gen_list:
            total_match_score += 1.0
            continue
        if not gt_list or not gen_list:
            continue
        gt_emb = gt_embeddings[cat]
        gen_emb = embedding_model.encode(gen_list)
        sim_mat = cosine_similarity(gen_emb, gt_emb)

        for i in range(len(gen_list)):
            best_sim = sim_mat[i].max()
            if best_sim >= similarity_threshold:
                total_match_score += 1.0
            else:
                sister_cat = SISTER_CATEGORIES.get(cat)
                if sister_cat and sister_cat in gt_embeddings:
                    sister_gt_emb = gt_embeddings[sister_cat]
                    sis_sim = cosine_similarity(gen_emb[i : i + 1], sister_gt_emb).max()
                    if sis_sim >= similarity_threshold:
                        total_match_score += partial_credit

    overall_ratio = total_match_score / max(min(total_gt, total_gen), 1.0)

    if overall_ratio >= match_threshold:
        return True, None
    return False, generate_feedback(
        gt_counts,
        gen_counts,
        "Feedback: Improve entity semantic similarity or check category assignment.",
    )

# %% [markdown]
# ## Iterative correction with feedback
# Run the complete pipeline

# %%
def run_pipeline(expanded_texts, raw_json_strings, ground_truth_entities, max_retries=MAX_RETRIES):
    """
    Run the complete entity extraction pipeline with iterative correction.
    Args:
        expanded_texts (list): List of expanded post texts
        raw_json_strings (list): List of raw JSON strings from initial extraction
        ground_truth_entities (list): List of ground truth entity dictionaries
        max_retries (int): Maximum number of retry attempts
    Returns:
        tuple: (extracted_json_entities, success_count)
    """
    extracted_json_entities = []
    success_count = 0

    for i in range(len(expanded_texts)):
        file_name = ground_truth_entities[i]['file_name']
        print(f"\nProcessing post {i+1}/{len(expanded_texts)}: {file_name}")
        print("------------------------------------")

        previous_attempt = None
        feedback = None
        standardized_json_obj = {}

        for attempt in range(max_retries):
            try:
                if attempt == 0:
                    raw_str = raw_json_strings[i]
                else:
                    raw_str = extract_entities_json(expanded_texts[i], feedback, previous_attempt)

                print(f"Attempt {attempt + 1}: Raw JSON string - {raw_str}")

                json_obj = parse_json_string(raw_str)
                print("Parsed successfully")
                standardized_json_obj = standardize_entities(json_obj)
                previous_attempt = raw_str

                print("Extracted: ", standardized_json_obj)
                print("Ground Truth: ", ground_truth_entities[i].get("entities", {}))

                completeness_verified, feedback_completeness = verify_completeness(
                    standardized_json_obj, ground_truth_entities[i].get("entities", {})
                )
                similarity_verified, feedback_similarity = verify_similarity(
                    standardized_json_obj, ground_truth_entities[i].get("entities", {})
                )
                if completeness_verified and similarity_verified:
                    print("ALL CHECKS PASSED!")
                    success_count += 1
                    break

                reasons = []
                if not completeness_verified: reasons.append("completeness verification failed")
                if not similarity_verified: reasons.append("similarity verification failed")
                print(f"Attempt {attempt + 1} failed: {', '.join(reasons)}")

                if not completeness_verified:
                    feedback = feedback_completeness
                else:
                    feedback = feedback_similarity

                if attempt < max_retries - 1:
                    print(f"Retrying with feedback: {feedback}")
                else:
                    print("Max retries reached. Using current result.")

            except json.JSONDecodeError as e:
                print(f"Attempt {attempt + 1} failed with error: {e}")
                if attempt < max_retries - 1:
                    feedback = f"JSON parsing error: {e}. Please ensure the output is valid JSON."
                    previous_attempt = None
                    print(f"Retrying with feedback: {feedback}")
                else:
                    print("Max retries reached. Using empty dictionary.")
                    standardized_json_obj = {}

        extracted_entities = {"file_name": file_name, "entities": standardized_json_obj}
        extracted_json_entities.append(extracted_entities)

    return extracted_json_entities, success_count

# %%
extracted_json_entities, success_count = run_pipeline(
    expanded_texts, raw_json_strings, standardized_annotated_posts
)

with open("extracted_entities.json", "w") as outfile:
    json.dump(extracted_json_entities, outfile)

print(f"Successfully processed {success_count} out of {len(expanded_texts)} posts.")
print(f"Success Rate: {success_count / len(expanded_texts) * 100:.2f}%")
# Out:
# Processing post 1/400: ARTHROTEC.1.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Arthrotec", "75"],
#   "ades": ["drowsy", "blurred vision", "weird feeling"],
#   "symptoms_diseases": ["arthritis", "agony"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Arthrotec', 'dextran 75'], 'ades': ['Drowsiness', 'Blurred vision', 'weird feeling'], 'symptoms_diseases': ['Arthritis', 'Agony']}
# Ground Truth:  {'drugs': ['Arthrotec'], 'ades': ['gastric problems', 'little blurred vision', 'feel a bit weird', 'bit drowsy'], 'symptoms_diseases': ['Agony', 'Arthritis', 'Growing pains']}
# ALL CHECKS PASSED!
#
# Processing post 2/400: ARTHROTEC.10.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": [],
#   "ades": [],
#   "symptoms_diseases": ["Hunger pangs", "Hip pain"]
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': [], 'symptoms_diseases': ['Hunger pangs', 'Hip joint pain']}
# Ground Truth:  {'drugs': [], 'ades': ['Hunger pangs'], 'symptoms_diseases': ['walk up & down steps sideways', 'Hip joint pain']}
# Attempt 1 failed: completeness verification failed
# Retrying with feedback: Feedback: Try extracting more 'ades' (expected 1, got 0).
# Attempt 2: Raw JSON string - {
#   "drugs": [],
#   "ades": [],
#   "symptoms_diseases": ["Hunger pangs", "Hip pain"]
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': [], 'symptoms_diseases': ['Hunger pangs', 'Hip joint pain']}
# Ground Truth:  {'drugs': [], 'ades': ['Hunger pangs'], 'symptoms_diseases': ['walk up & down steps sideways', 'Hip joint pain']}
# Attempt 2 failed: completeness verification failed
# Retrying with feedback: Feedback: Try extracting more 'ades' (expected 1, got 0).
# Attempt 3: Raw JSON string - {
#   "drugs": [],
#   "ades": [],
#   "symptoms_diseases": ["Hunger pangs", "Hip pain"]
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': [], 'symptoms_diseases': ['Hunger pangs', 'Hip joint pain']}
# Ground Truth:  {'drugs': [], 'ades': ['Hunger pangs'], 'symptoms_diseases': ['walk up & down steps sideways', 'Hip joint pain']}
# Attempt 3 failed: completeness verification failed
# Max retries reached. Using current result.
#
# Processing post 3/400: ARTHROTEC.100.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["vaginal bleeding", "stomach pain", "canker sores", "headache", "bleeding"],
#   "symptoms_diseases": ["menstrual cycle", "pain"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Vaginal Hemorrhage', 'Stomach ache', 'Aphthous Stomatitis', 'Headache', 'Hemorrhage'], 'symptoms_diseases': ['Onset of menstrual cycle', 'Pain']}
# Ground Truth:  {'drugs': [], 'ades': ['Vaginal Hemorrhage', 'Headache', 'Aphthous Stomatitis', 'Stomach ache'], 'symptoms_diseases': ['Pain']}
# ALL CHECKS PASSED!
#
# Processing post 4/400: ARTHROTEC.101.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": [],
#   "ades": ["shortness of breath", "sense of depression", "cramping", "upset stomach"],
#   "symptoms_diseases": []
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Dyspnea', 'sense of depression', 'Cramping sensation quality', 'Upset stomach'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': [], 'ades': ['Upset stomach', 'Depression - motion', 'Cramping sensation quality', 'Dyspnea'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 5/400: ARTHROTEC.102.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": ["Arthrotec"],
#   "ades": ["can't stand or walk for any lengths of time"],
#   "symptoms_diseases": []
# }
# Parsed successfully
# Extracted:  {'drugs': ['Arthrotec'], 'ades': ["can't stand or walk for any lengths of time"], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': ['Arthrotec'], 'ades': [], 'symptoms_diseases': ["I can't stand or walk for any lengths of time"]}
# Attempt 1 failed: similarity verification failed
# Retrying with feedback: Feedback: Try extracting fewer 'ades' (expected 0, got 1), more 'symptoms_diseases' (expected 1, got 0).
# Attempt 2: Raw JSON string - {
#   "drugs": ["Arthrotec"],
#   "ades": [],
#   "symptoms_diseases": ["can't stand or walk for any lengths of time"]
# }
# Parsed successfully
# Extracted:  {'drugs': ['Arthrotec'], 'ades': [], 'symptoms_diseases': ["can't stand or walk for any lengths of time"]}
# Ground Truth:  {'drugs': ['Arthrotec'], 'ades': [], 'symptoms_diseases': ["I can't stand or walk for any lengths of time"]}
# ALL CHECKS PASSED!
#
# Processing post 6/400: ARTHROTEC.103.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Arthrotox"],
#   "ades": ["bleeding forever", "pain and stiffness", "felt weak and almost fainted"],
#   "symptoms_diseases": []
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Arthrotox'], 'ades': ['bleeding forever', 'pain and stiffness', 'felt weak and almost fainted'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': ['Arthotec'], 'ades': ['so much pain', 'feel weak and almost fainted', 'Hemorrhage'], 'symptoms_diseases': ['pain and stiffness']}
# Attempt 1 failed: completeness verification failed
# Retrying with feedback: Feedback: Try extracting more 'symptoms_diseases' (expected 1, got 0).
# Attempt 2: Raw JSON string - ```json
# {
#   "drugs": ["Arthrotox"],
#   "ades": ["bleeding forever", "pain and stiffness", "felt weak and almost fainted"],
#   "symptoms_diseases": ["pain and stiffness"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Arthrotox'], 'ades': ['bleeding forever', 'pain and stiffness', 'felt weak and almost fainted'], 'symptoms_diseases': ['pain and stiffness']}
# Ground Truth:  {'drugs': ['Arthotec'], 'ades': ['so much pain', 'feel weak and almost fainted', 'Hemorrhage'], 'symptoms_diseases': ['pain and stiffness']}
# ALL CHECKS PASSED!
#
# Processing post 7/400: ARTHROTEC.104.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["diarrhea", "constipation", "fatigue"],
#   "symptoms_diseases": ["severe osteoarthritis"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Diarrhea', 'Constipation', 'Fatigue'], 'symptoms_diseases': ['severe osteoarthritis']}
# Ground Truth:  {'drugs': [], 'ades': ['Diarrhea', 'Constipation', 'Fatigue'], 'symptoms_diseases': ['severe osteoarthritis in the knees', 'severe osteoarthritis in the hands', "the heel I couldn't walk on very well", 'Pain']}
# ALL CHECKS PASSED!
#
# Processing post 8/400: ARTHROTEC.105.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Arthrotec"],
#   "ades": ["body swelling", "face swelling", "wrist swelling", "abdomen swelling", "thigh swelling", "insomnia", "forgetfulness", "confusion", "loose stools"],
#   "symptoms_diseases": ["tight clothes fit", "empty stomach feeling", "loose stools"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Arthrotec'], 'ades': ['Swelling of body structure', 'Facial swelling (finding)', 'Swelling of wrist joint', 'Abdomen distended', 'thigh swelling', 'Sleeplessness', 'Age-associated memory impairment', 'Clouded consciousness', 'Loose stool'], 'symptoms_diseases': ['tight clothes fit', 'empty stomach feeling', 'Loose stool']}
# Ground Truth:  {'drugs': ['Arthrotec', 'HA (Hyaluronic Acid)'], 'ades': ['"empty stomach" feeling', 'Loose stool', 'Insomina', 'Swelling of body structure', 'Facial swelling (finding)', 'forgetfulnes and confussion', 'swelling thighs', 'Bilateral swelling of wrist joints', 'Abdomen distended'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 9/400: ARTHROTEC.106.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Arthrotec"],
#   "ades": [],
#   "symptoms_diseases": ["arthritis", "knee replacement"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Arthrotec'], 'ades': [], 'symptoms_diseases': ['Arthritis', 'Knee Replacement Arthroplasty']}
# Ground Truth:  {'drugs': ['Arthrotec', 'Arthrotec'], 'ades': [], 'symptoms_diseases': ['Arthritis', 'Pain']}
# ALL CHECKS PASSED!
#
# Processing post 10/400: ARTHROTEC.107.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": [],
#   "ades": [],
#   "symptoms_diseases": ["extreme rectal bleed", "sick", "hospitalization"]
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': [], 'symptoms_diseases': ['extreme rectal bleed', 'Sick Sinus Syndrome', 'Home hospitalization']}
# Ground Truth:  {'drugs': [], 'ades': ['Rectal hemorrhage', 'felt I might not survive', 'extremely sick'], 'symptoms_diseases': []}
# Attempt 1 failed: completeness verification failed, similarity verification failed
# Retrying with feedback: Feedback: Try extracting more 'ades' (expected 3, got 0), fewer 'symptoms_diseases' (expected 0, got 3).
# Attempt 2: Raw JSON string - {
#   "drugs": [],
#   "ades": ["extreme rectal bleed", "sick", "hospitalization"],
#   "symptoms_diseases": []
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['extreme rectal bleed', 'Sick Sinus Syndrome', 'Home hospitalization'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': [], 'ades': ['Rectal hemorrhage', 'felt I might not survive', 'extremely sick'], 'symptoms_diseases': []}
# Attempt 2 failed: completeness verification failed
# Retrying with feedback: Feedback: Check entity accuracy or category assignment.
# Attempt 3: Raw JSON string - {
#   "drugs": [],
#   "ades": ["extreme rectal bleed", "sick", "hospitalization"],
#   "symptoms_diseases": []
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['extreme rectal bleed', 'Sick Sinus Syndrome', 'Home hospitalization'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': [], 'ades': ['Rectal hemorrhage', 'felt I might not survive', 'extremely sick'], 'symptoms_diseases': []}
# Attempt 3 failed: completeness verification failed
# Max retries reached. Using current result.
#
# Processing post 11/400: ARTHROTEC.108.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": ["Arthrotec"],
#   "ades": ["Abdominal pain", "Dizzieness", "blood clots in urine"],
#   "symptoms_diseases": ["Abdominal pain", "Dizzieness", "blood clots in urine"]
# }
# Parsed successfully
# Extracted:  {'drugs': ['Arthrotec'], 'ades': ['Abdominal Pain', 'Dizziness', 'Blood clots in urine'], 'symptoms_diseases': ['Abdominal Pain', 'Dizziness', 'Blood clots in urine']}
# Ground Truth:  {'drugs': ['Arthrotec'], 'ades': ['Dizziness', 'Urinary Incontinence', 'Blood clots in urine', 'Abdominal Pain'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 12/400: ARTHROTEC.109.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": [],
#   "ades": ["Upset stomach", "feeling that I may need to throw up", "pain in my stomach", "feeling like I may need to go to the restroom", "can't go to the restroom"],
#   "symptoms_diseases": ["Upset stomach", "feeling that I may need to throw up", "pain in my stomach", "feeling like I may need to go to the restroom", "can't go to the restroom"]
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Upset stomach', 'feeling that I may need to throw up', 'pain in my stomach', 'feeling like I may need to go to the restroom', "can't go to the restroom"], 'symptoms_diseases': ['Upset stomach', 'feeling that I may need to throw up', 'pain in my stomach', 'feeling like I may need to go to the restroom', "can't go to the restroom"]}
# Ground Truth:  {'drugs': [], 'ades': ['pain in my stomach', 'throw up', 'Upset stomach', 'deep constant pain', "I may need to go to the restroom, but when I do I can't"], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 13/400: ARTHROTEC.11.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Arthrotec"],
#   "ades": [],
#   "symptoms_diseases": ["pain", "shoulder"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Arthrotec'], 'ades': [], 'symptoms_diseases': ['Pain', 'Shoulder']}
# Ground Truth:  {'drugs': ['Arthrotec'], 'ades': [], 'symptoms_diseases': ['Pain']}
# ALL CHECKS PASSED!
#
# Processing post 14/400: ARTHROTEC.110.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["diarrhea", "uterine cramps", "heavy menstrual bleeding", "gas", "nausea", "more pain"],
#   "symptoms_diseases": []
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Diarrhea', 'uterine cramps', 'Menorrhagia', 'Gas Dosage Form', 'Nausea', 'Chronic pain in coccyx for more than three months'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': [], 'ades': ['Diarrhea', 'Pain', 'uterine cramps', 'Alot of gas', 'Nausea', 'Menorrhagia'], 'symptoms_diseases': ['Pain', 'Pain']}
# ALL CHECKS PASSED!
#
# Processing post 15/400: ARTHROTEC.111.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": [],
#   "symptoms_diseases": ["swelling", "injury", "stomach pain"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': [], 'symptoms_diseases': ['Swelling', 'Traumatic AND/OR non-traumatic injury', 'Stomach ache']}
# Ground Truth:  {'drugs': [], 'ades': ['little gas'], 'symptoms_diseases': ['Swelling', 'extreme stomach pain', 'Swelling']}
# ALL CHECKS PASSED!
#
# Processing post 16/400: ARTHROTEC.112.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": [],
#   "ades": ["stomach pain", "constipation", "uterine cramps", "pain in the ovaries", "pressure in the stomach", "severe stomach pain", "constant burping", "bad trip"],
#   "symptoms_diseases": ["menopausal", "urinary retention", "burping"]
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Stomach ache', 'Constipation', 'uterine cramps', 'pain in the ovaries', 'pressure in the stomach', 'severe stomach pain', 'constant burping', 'Psychoactive substance-induced organic hallucinosis'], 'symptoms_diseases': ['Menopausal syndrome', 'Urinary Retention', 'Eructation']}
# Ground Truth:  {'drugs': [], 'ades': ['Constipation', 'uterine, cramps (menopausal for 20 years)', 'severe stomach pain', "couldn't urinate", 'horrible stomach pain', 'pressure in the stomach', 'constant burping', 'pain in the ovaries (menopausal for 20 years)'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 17/400: ARTHROTEC.113.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["stomach cramping", "uterus spasms", "nausea", "bleeding"],
#   "symptoms_diseases": ["back pain", "menstrual cycle"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Stomach cramps (finding)', 'Uterine spasm', 'Nausea', 'Hemorrhage'], 'symptoms_diseases': ['Back Pain', 'Onset of menstrual cycle']}
# Ground Truth:  {'drugs': ['Arthrotec'], 'ades': ['Pain', 'Pain', 'Stomach cramps (finding)', 'Nausea', 'worst pain I have ever experienced', 'uterus starting to have spasms', 'uterus pain and cramping', 'bleeding and I was on day 12 of my cycle', 'PAROXYSMAL EXTREME PAIN DISORDER'], 'symptoms_diseases': ['Back Pain', 'period cramps']}
# ALL CHECKS PASSED!
#
# Processing post 18/400: ARTHROTEC.114.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["ibuprofen", "Celebrex"],
#   "ades": ["severe stomach cramping", "high blood pressure", "ankle swelling"],
#   "symptoms_diseases": ["stomach pain", "high blood pressure", "ankle swelling"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['ibuprofen', 'Celebrex'], 'ades': ['severe stomach cramping', 'Hypertensive disease', 'Ankle edema (finding)'], 'symptoms_diseases': ['Stomach ache', 'Hypertensive disease', 'Ankle edema (finding)']}
# Ground Truth:  {'drugs': ['Celebrex'], 'ades': ['Stomach ache', 'Hypertensive disease', 'Ankle edema (finding)', 'severe stomach cramping'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 19/400: ARTHROTEC.115.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": [],
#   "ades": [],
#   "symptoms_diseases": ["Stomach cramps", "gassy", "pain"]
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': [], 'symptoms_diseases': ['Stomach cramps (finding)', 'Salmonella Gassi', 'Pain']}
# Ground Truth:  {'drugs': [], 'ades': ['Salmonella Gassi', 'Stomach cramps (finding)'], 'symptoms_diseases': ['Pain', 'Pain']}
# ALL CHECKS PASSED!
#
# Processing post 20/400: ARTHROTEC.116.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": [],
#   "ades": ["Swelling", "weight increase", "No relief in pain"],
#   "symptoms_diseases": ["Swelling", "weight increase", "No relief in pain"]
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Swelling', 'Weight increase consultation', 'No relief in pain'], 'symptoms_diseases': ['Swelling', 'Weight increase consultation', 'No relief in pain']}
# Ground Truth:  {'drugs': [], 'ades': ['Weight increase consultation', 'Swelling'], 'symptoms_diseases': ['Pain']}
# ALL CHECKS PASSED!
#
# Processing post 21/400: ARTHROTEC.117.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": [],
#   "ades": ["kidney function", "stomach (acid reflux)", "diarrhea"],
#   "symptoms_diseases": ["Diarrhea", "kidney function"]
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Kidney Function Tests', 'stomach (acid reflux)', 'Diarrhea'], 'symptoms_diseases': ['Diarrhea', 'Kidney Function Tests']}
# Ground Truth:  {'drugs': [], 'ades': ['Diarrhea', 'affecting my stomach(acid reflux)', 'Diarrhea', 'affecting my kidneys'], 'symptoms_diseases': ['Arthritis Pain']}
# ALL CHECKS PASSED!
#
# Processing post 22/400: ARTHROTEC.118.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": [],
#   "ades": ["appetite increase"],
#   "symptoms_diseases": ["stomach feels empty all the time", "pain feels better"]
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Increased appetite (finding)'], 'symptoms_diseases': ['stomach feels empty all the time', 'pain feels better']}
# Ground Truth:  {'drugs': [], 'ades': ['stomach feels empty all the time', 'Increased appetite (finding)', 'Increased appetite (finding)'], 'symptoms_diseases': ['Pain']}
# ALL CHECKS PASSED!
#
# Processing post 23/400: ARTHROTEC.119.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["headache"],
#   "symptoms_diseases": ["headache", "dizziness"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Headache'], 'symptoms_diseases': ['Headache', 'Dizziness']}
# Ground Truth:  {'drugs': [], 'ades': ['Headache', 'Dizziness', 'Headache'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 24/400: ARTHROTEC.12.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["stomach sensitivity"],
#   "symptoms_diseases": ["severely restricted", "walk less than 100 meters", "walk 1/2 km", "function"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['stomach sensitivity'], 'symptoms_diseases': ['Asthma severely restricts exercise', 'walk less than 100 meters', 'walk 1/2 km', 'Function (attribute)']}
# Ground Truth:  {'drugs': [], 'ades': ['stomach sensitivity'], 'symptoms_diseases': ['severly restricted', 'could only walk less than 100 meters']}
# ALL CHECKS PASSED!
#
# Processing post 25/400: ARTHROTEC.120.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["pills"],
#   "ades": ["extreme uterine cramping", "cold sweat", "shaking uncontrollably", "nauseated", "several bowel movements", "going to pass out", "vaginal bleeding"],
#   "symptoms_diseases": ["uterine cramping", "cold sweat", "nausea", "bowel movements", "going into shock", "vaginal bleeding", "cycle"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Pills'], 'ades': ['extreme uterine cramping', 'Cold sweat', 'shaking uncontrollably', 'Nausea', 'several bowel movements', 'going to pass out', 'Vaginal Hemorrhage'], 'symptoms_diseases': ['uterine cramping', 'Cold sweat', 'Nausea', 'Defecation', 'going into shock', 'Vaginal Hemorrhage', 'Menstrual cycle']}
# Ground Truth:  {'drugs': ['ibuprofen'], 'ades': ['Pain', 'several bowel movements', 'Nausea', 'It felt like I was having a baby', 'cold sweat, shaking uncontrollably', 'uterine cramping', 'I felt like I was going to pass out', 'gut wrenching pain', 'vaginal bleeding and I am only 11 days into my cycle', 'going into shock'], 'symptoms_diseases': []}
# Attempt 1 failed: completeness verification failed, similarity verification failed
# Retrying with feedback: Feedback: Try extracting more 'ades' (expected 10, got 7), fewer 'symptoms_diseases' (expected 0, got 7).
# Attempt 2: Raw JSON string - ```json
# {
#   "drugs": ["pills"],
#   "ades": ["extreme uterine cramping", "cold sweat", "shaking uncontrollably", "nauseated", "several bowel movements", "going to pass out", "vaginal bleeding"],
#   "symptoms_diseases": ["uterine cramping", "cold sweat", "nausea", "bowel movements", "going into shock", "vaginal bleeding", "cycle"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Pills'], 'ades': ['extreme uterine cramping', 'Cold sweat', 'shaking uncontrollably', 'Nausea', 'several bowel movements', 'going to pass out', 'Vaginal Hemorrhage'], 'symptoms_diseases': ['uterine cramping', 'Cold sweat', 'Nausea', 'Defecation', 'going into shock', 'Vaginal Hemorrhage', 'Menstrual cycle']}
# Ground Truth:  {'drugs': ['ibuprofen'], 'ades': ['Pain', 'several bowel movements', 'Nausea', 'It felt like I was having a baby', 'cold sweat, shaking uncontrollably', 'uterine cramping', 'I felt like I was going to pass out', 'gut wrenching pain', 'vaginal bleeding and I am only 11 days into my cycle', 'going into shock'], 'symptoms_diseases': []}
# Attempt 2 failed: completeness verification failed, similarity verification failed
# Retrying with feedback: Feedback: Try extracting more 'ades' (expected 10, got 7), fewer 'symptoms_diseases' (expected 0, got 7).
# Attempt 3: Raw JSON string - ```json
# {
#   "drugs": ["pills"],
#   "ades": ["extreme uterine cramping", "cold sweat", "shaking uncontrollably", "nauseated", "several bowel movements", "going to pass out", "vaginal bleeding"],
#   "symptoms_diseases": ["uterine cramping", "cold sweat", "nausea", "bowel movements", "going into shock", "vaginal bleeding", "cycle"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Pills'], 'ades': ['extreme uterine cramping', 'Cold sweat', 'shaking uncontrollably', 'Nausea', 'several bowel movements', 'going to pass out', 'Vaginal Hemorrhage'], 'symptoms_diseases': ['uterine cramping', 'Cold sweat', 'Nausea', 'Defecation', 'going into shock', 'Vaginal Hemorrhage', 'Menstrual cycle']}
# Ground Truth:  {'drugs': ['ibuprofen'], 'ades': ['Pain', 'several bowel movements', 'Nausea', 'It felt like I was having a baby', 'cold sweat, shaking uncontrollably', 'uterine cramping', 'I felt like I was going to pass out', 'gut wrenching pain', 'vaginal bleeding and I am only 11 days into my cycle', 'going into shock'], 'symptoms_diseases': []}
# Attempt 3 failed: completeness verification failed, similarity verification failed
# Max retries reached. Using current result.
#
# Processing post 26/400: ARTHROTEC.121.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": [],
#   "ades": ["dizziness", "stomach cramps", "disorientation", "ulceration of the esophagus", "stomach ulcer", "gut infection", "side effects"],
#   "symptoms_diseases": ["exhaustion", "depression"]
# }
# Parsed successfully
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Streaming output truncated to the last 5000 lines.
# Parsed successfully
# Extracted:  {'drugs': ['Cataflam'], 'ades': ['rectal bleeding/collitis'], 'symptoms_diseases': ['GI distress']}
# Ground Truth:  {'drugs': ['Cataflam', 'Cataflam'], 'ades': ['Rectal hemorrhage', 'collitis', 'GI distress'], 'symptoms_diseases': []}
# Attempt 1 failed: completeness verification failed, similarity verification failed
# Retrying with feedback: Feedback: Try extracting more 'drugs' (expected 2, got 1), more 'ades' (expected 3, got 1), fewer 'symptoms_diseases' (expected 0, got 1).
# Attempt 2: Raw JSON string - {
#   "drugs": ["Cataflam"],
#   "ades": ["rectal bleeding/collitis", "GI distress", "hospitalization"],
#   "symptoms_diseases": ["GI distress"]
# }
# Parsed successfully
# Extracted:  {'drugs': ['Cataflam'], 'ades': ['rectal bleeding/collitis', 'GI distress', 'Home hospitalization'], 'symptoms_diseases': ['GI distress']}
# Ground Truth:  {'drugs': ['Cataflam', 'Cataflam'], 'ades': ['Rectal hemorrhage', 'collitis', 'GI distress'], 'symptoms_diseases': []}
# Attempt 2 failed: similarity verification failed
# Retrying with feedback: Feedback: Try extracting more 'drugs' (expected 2, got 1), fewer 'symptoms_diseases' (expected 0, got 1).
# Attempt 3: Raw JSON string - {
#   "drugs": ["Cataflam"],
#   "ades": ["rectal bleeding/collitis", "GI distress", "hospitalization"],
#   "symptoms_diseases": ["GI distress"]
# }
# Parsed successfully
# Extracted:  {'drugs': ['Cataflam'], 'ades': ['rectal bleeding/collitis', 'GI distress', 'Home hospitalization'], 'symptoms_diseases': ['GI distress']}
# Ground Truth:  {'drugs': ['Cataflam', 'Cataflam'], 'ades': ['Rectal hemorrhage', 'collitis', 'GI distress'], 'symptoms_diseases': []}
# Attempt 3 failed: similarity verification failed
# Max retries reached. Using current result.
#
# Processing post 152/400: CATAFLAM.2.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": ["propain", "mypaid forte", "Ibuprofen", "Paracetamol"],
#   "ades": ["dry mouth"],
#   "symptoms_diseases": ["pain"]
# }
# Parsed successfully
# Extracted:  {'drugs': ['propain', 'mypaid forte', 'ibuprofen', 'acetaminophen 500 MG / metoclopramide 5 MG Oral Tablet'], 'ades': ['Xerostomia'], 'symptoms_diseases': ['Pain']}
# Ground Truth:  {'drugs': ['propain', 'mypaid forte', 'Paracetamol 325 mg', 'ibuprofen 400 MG'], 'ades': ['Xerostomia'], 'symptoms_diseases': ['Pain']}
# ALL CHECKS PASSED!
#
# Processing post 153/400: CATAFLAM.3.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": [],
#   "ades": ["stomach pains", "gass", "dry mouth", "drowsiness"],
#   "symptoms_diseases": []
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Stomach ache', 'Gass classification', 'Xerostomia', 'Drowsiness'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': [], 'ades': ['Stomach ache', 'Xerostomia', 'Drowsiness', 'Gass classification'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 154/400: CATAFLAM.4.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["drowsiness", "dry mouth"],
#   "symptoms_diseases": []
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Drowsiness', 'Xerostomia'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': ['Vioxx'], 'ades': ['Drowsiness', 'Xerostomia', 'Drowsiness'], 'symptoms_diseases': ['Pain', 'Growing pains', 'Pain', 'Generalized aches and pains']}
# Attempt 1 failed: completeness verification failed
# Retrying with feedback: Feedback: Try extracting more 'drugs' (expected 1, got 0), more 'ades' (expected 3, got 2), more 'symptoms_diseases' (expected 4, got 0).
# Attempt 2: Raw JSON string - ```json
# {
#   "drugs": ["NSAID", "Vioxx", "OTC stuff"],
#   "ades": ["drowsiness", "dry mouth", "lowered pain level"],
#   "symptoms_diseases": ["pain"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['NSAID', 'Vioxx', 'OTC stuff'], 'ades': ['Drowsiness', 'Xerostomia', 'lowered pain level'], 'symptoms_diseases': ['Pain']}
# Ground Truth:  {'drugs': ['Vioxx'], 'ades': ['Drowsiness', 'Xerostomia', 'Drowsiness'], 'symptoms_diseases': ['Pain', 'Growing pains', 'Pain', 'Generalized aches and pains']}
# Attempt 2 failed: similarity verification failed
# Retrying with feedback: Feedback: Try extracting fewer 'drugs' (expected 1, got 3), more 'symptoms_diseases' (expected 4, got 1).
# Attempt 3: Raw JSON string - ```json
# {
#   "drugs": ["NSAID", "Vioxx", "OTC stuff"],
#   "ades": ["drowsiness", "dry mouth", "lowered pain level"],
#   "symptoms_diseases": ["pain", "drowsiness", "dry mouth", "lowered pain level"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['NSAID', 'Vioxx', 'OTC stuff'], 'ades': ['Drowsiness', 'Xerostomia', 'lowered pain level'], 'symptoms_diseases': ['Pain', 'Drowsiness', 'Xerostomia', 'lowered pain level']}
# Ground Truth:  {'drugs': ['Vioxx'], 'ades': ['Drowsiness', 'Xerostomia', 'Drowsiness'], 'symptoms_diseases': ['Pain', 'Growing pains', 'Pain', 'Generalized aches and pains']}
# ALL CHECKS PASSED!
#
# Processing post 155/400: CATAFLAM.5.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Cataflam"],
#   "ades": ["Stevens Johnson Syndrome"],
#   "symptoms_diseases": []
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Cataflam'], 'ades': ['Stevens-Johnson Syndrome'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': ['Cataflam'], 'ades': ['Stevens-Johnson Syndrome'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 156/400: CATAFLAM.6.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": ["NSAID"],
#   "ades": ["Lower gut pain", "diarrhea"],
#   "symptoms_diseases": []
# }
# Parsed successfully
# Extracted:  {'drugs': ['NSAID'], 'ades': ['Lower gut pain', 'Diarrhea'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': [], 'ades': ['Lower gut pain', 'diahrrea', 'Gastrointestinal problem'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 157/400: CATAFLAM.7.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Vioxx", "Celecoxib", "Bextra", "Cataflam"],
#   "ades": [],
#   "symptoms_diseases": ["blood pressure"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Vioxx', 'celecoxib', 'Bextra', 'Cataflam'], 'ades': [], 'symptoms_diseases': ['Blood Pressure']}
# Ground Truth:  {'drugs': ['Vioxx', 'Bextra', 'Celebrx', 'Cataflam', 'Cataflam'], 'ades': ['slight effect on my blood pressure'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 158/400: CATAFLAM.8.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": ["ibuprofen"],
#   "ades": ["sun sensitivity"],
#   "symptoms_diseases": []
# }
# Parsed successfully
# Extracted:  {'drugs': ['ibuprofen'], 'ades': ['Constitutional sun sensitivity finding'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': ['ibuprofen', 'Ibu'], 'ades': ['Constitutional sun sensitivity finding'], 'symptoms_diseases': ['Pain', 'Inflammation']}
# Attempt 1 failed: completeness verification failed
# Retrying with feedback: Feedback: Try extracting more 'drugs' (expected 2, got 1), more 'symptoms_diseases' (expected 2, got 0).
# Attempt 2: Raw JSON string - {
#   "drugs": ["ibuprofen"],
#   "ades": ["sun sensitivity"],
#   "symptoms_diseases": ["pain", "inflammation"]
# }
# Parsed successfully
# Extracted:  {'drugs': ['ibuprofen'], 'ades': ['Constitutional sun sensitivity finding'], 'symptoms_diseases': ['Pain', 'Inflammation']}
# Ground Truth:  {'drugs': ['ibuprofen', 'Ibu'], 'ades': ['Constitutional sun sensitivity finding'], 'symptoms_diseases': ['Pain', 'Inflammation']}
# ALL CHECKS PASSED!
#
# Processing post 159/400: CATAFLAM.9.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Cataflam", "Demerol"],
#   "ades": ["gassy abdominal cramping", "heart attacks", "strokes"],
#   "symptoms_diseases": ["Endometriosis", "Sciatic Endo", "lower lumbar arthritis", "dysmennorhea"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Cataflam', 'Demerol'], 'ades': ['gassy abdominal cramping', 'Myocardial Infarction', 'Cathepsin A-related arteriopathy, strokes, leukoencephalopathy'], 'symptoms_diseases': ['Endometriosis', 'Sciatic Endo', 'lower lumbar arthritis', 'dysmennorhea']}
# Ground Truth:  {'drugs': ['Cataflam', 'Demerol'], 'ades': ['gassy abdominal cramping'], 'symptoms_diseases': ['Pain', 'Pain', 'Endometriosis', 'Sciatic Endo', 'dysmennorhea', 'lower lumbar arthritis', 'Myocardial Infarction', 'Cathepsin A-related arteriopathy, strokes, leukoencephalopathy']}
# ALL CHECKS PASSED!
#
# Processing post 160/400: DICLOFENAC-POTASSIUM.1.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": [],
#   "ades": [],
#   "symptoms_diseases": ["severe pain"]
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': [], 'symptoms_diseases': ['Severe pain']}
# Ground Truth:  {'drugs': [], 'ades': [], 'symptoms_diseases': ['Severe pain']}
# ALL CHECKS PASSED!
#
# Processing post 161/400: DICLOFENAC-POTASSIUM.2.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": [],
#   "ades": [],
#   "symptoms_diseases": ["decrease in pain"]
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': [], 'symptoms_diseases': ['decrease in pain']}
# Ground Truth:  {'drugs': [], 'ades': [], 'symptoms_diseases': ['Pain']}
# ALL CHECKS PASSED!
#
# Processing post 162/400: DICLOFENAC-POTASSIUM.3.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["3 esophageal ulcers", "can't eat or drink", "always sick"],
#   "symptoms_diseases": ["throat pain", "esophageal ulcers", "can't eat or drink", "always sick"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['3 esophageal ulcers', "can't eat or drink", 'always sick'], 'symptoms_diseases': ['Sore Throat', 'Ulcer of esophagus', "can't eat or drink", 'always sick']}
# Ground Truth:  {'drugs': [], 'ades': ['Sore Throat', 'esofogual uclers', "can't eat normal", "couldn't eat or drink"], 'symptoms_diseases': ['Sick Sinus Syndrome']}
# ALL CHECKS PASSED!
#
# Processing post 163/400: DICLOFENAC-SODIUM.1.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Ibuprofen"],
#   "ades": ["drowsy", "tired", "no pain relief"],
#   "symptoms_diseases": []
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['ibuprofen'], 'ades': ['Drowsiness', 'Feeling tired', 'no pain relief'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': ['Aleve', 'Aleve', 'Aleve'], 'ades': ['Feeling tired', 'Drowsiness'], 'symptoms_diseases': ['Pain', 'Pain']}
# Attempt 1 failed: completeness verification failed, similarity verification failed
# Retrying with feedback: Feedback: Try extracting more 'drugs' (expected 3, got 1), fewer 'ades' (expected 2, got 3), more 'symptoms_diseases' (expected 2, got 0).
# Attempt 2: Raw JSON string - ```json
# {
#   "drugs": ["Ibuprofen", "Ibuprofen", "Ibuprofen"],
#   "ades": ["drowsy", "tired"],
#   "symptoms_diseases": ["pain"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['ibuprofen', 'ibuprofen', 'ibuprofen'], 'ades': ['Drowsiness', 'Feeling tired'], 'symptoms_diseases': ['Pain']}
# Ground Truth:  {'drugs': ['Aleve', 'Aleve', 'Aleve'], 'ades': ['Feeling tired', 'Drowsiness'], 'symptoms_diseases': ['Pain', 'Pain']}
# Attempt 2 failed: completeness verification failed, similarity verification failed
# Retrying with feedback: Feedback: Try extracting more 'symptoms_diseases' (expected 2, got 1).
# Attempt 3: Raw JSON string - ```json
# {
#   "drugs": ["Ibuprofen", "Ibuprofen", "Ibuprofen"],
#   "ades": ["drowsy", "tired"],
#   "symptoms_diseases": ["pain", "pain"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['ibuprofen', 'ibuprofen', 'ibuprofen'], 'ades': ['Drowsiness', 'Feeling tired'], 'symptoms_diseases': ['Pain', 'Pain']}
# Ground Truth:  {'drugs': ['Aleve', 'Aleve', 'Aleve'], 'ades': ['Feeling tired', 'Drowsiness'], 'symptoms_diseases': ['Pain', 'Pain']}
# Attempt 3 failed: completeness verification failed, similarity verification failed
# Max retries reached. Using current result.
#
# Processing post 164/400: DICLOFENAC-SODIUM.2.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["swelling of the legs and feet", "bad bladder infection", "pain", "side effects"],
#   "symptoms_diseases": ["headache", "high blood pressure", "bladder infection", "pain"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['swelling of the legs and feet', 'bad bladder infection', 'Pain', 'Warfarin side effects'], 'symptoms_diseases': ['Headache', 'Hypertensive disease', 'Cystitis', 'Pain']}
# Ground Truth:  {'drugs': ['Aleve'], 'ades': ['Headache', 'SWELLING OF THE LEGS AND FEET', 'Hypertensive disease', 'Swelling', 'BLADDER NOT TO EMPTY AS IT SHOULD', 'Cystitis', 'Cystitis'], 'symptoms_diseases': ['Pain']}
# ALL CHECKS PASSED!
#
# Processing post 165/400: DICLOFENAC-SODIUM.3.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Arthrotec"],
#   "ades": ["vaginal bleeding", "skin burns", "diarrhea", "breast pain", "erythema", "dry skin", "cuts on hands", "excessive sweating", "pruritus ani"],
#   "symptoms_diseases": ["menopausal symptoms", "arthritic symptoms"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Arthrotec'], 'ades': ['Vaginal Hemorrhage', 'Electrical burn of skin', 'Diarrhea', 'Mastodynia', 'Erythema', 'Xeroderma', 'cuts on hands', 'Increased sweating', 'Pruritus Ani'], 'symptoms_diseases': ['Menopausal symptom', 'arthritic symptoms']}
# Ground Truth:  {'drugs': ['Arthrotec', 'Arthrotec'], 'ades': ['Vaginal Hemorrhage', 'Mastodynia', 'erithema', 'skin is so dry', 'sweating a lot', 'Pruritus', 'Diarrhea', 'Vaginal Hemorrhage', 'Pruritus', 'skin was all red', 'vaginal skin burns', 'cycle was back', 'cuts on my hands'], 'symptoms_diseases': ['Pain']}
# Attempt 1 failed: similarity verification failed
# Retrying with feedback: Feedback: Try extracting more 'drugs' (expected 2, got 1), more 'ades' (expected 13, got 9), fewer 'symptoms_diseases' (expected 1, got 2).
# Attempt 2: Raw JSON string - ```json
# {
#   "drugs": ["Arthrotec"],
#   "ades": ["vaginal bleeding", "skin burns", "diarrhea", "breast pain", "erythema", "dry skin", "cuts on hands", "excessive sweating", "pruritus ani", "menopausal symptoms", "arthritic symptoms"],
#   "symptoms_diseases": ["menopausal symptoms"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Arthrotec'], 'ades': ['Vaginal Hemorrhage', 'Electrical burn of skin', 'Diarrhea', 'Mastodynia', 'Erythema', 'Xeroderma', 'cuts on hands', 'Increased sweating', 'Pruritus Ani', 'Menopausal symptom', 'arthritic symptoms'], 'symptoms_diseases': ['Menopausal symptom']}
# Ground Truth:  {'drugs': ['Arthrotec', 'Arthrotec'], 'ades': ['Vaginal Hemorrhage', 'Mastodynia', 'erithema', 'skin is so dry', 'sweating a lot', 'Pruritus', 'Diarrhea', 'Vaginal Hemorrhage', 'Pruritus', 'skin was all red', 'vaginal skin burns', 'cycle was back', 'cuts on my hands'], 'symptoms_diseases': ['Pain']}
# Attempt 2 failed: similarity verification failed
# Retrying with feedback: Feedback: Try extracting more 'drugs' (expected 2, got 1), more 'ades' (expected 13, got 11).
# Attempt 3: Raw JSON string - ```json
# {
#   "drugs": ["Arthrotec"],
#   "ades": ["vaginal bleeding", "skin burns", "diarrhea", "breast pain", "erythema", "dry skin", "cuts on hands", "excessive sweating", "pruritus ani", "menopausal symptoms", "arthritic symptoms", "menstrual bleeding", "pruritus", "erythema", "skin redness"],
#   "symptoms_diseases": ["menopausal symptoms"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Arthrotec'], 'ades': ['Vaginal Hemorrhage', 'Electrical burn of skin', 'Diarrhea', 'Mastodynia', 'Erythema', 'Xeroderma', 'cuts on hands', 'Increased sweating', 'Pruritus Ani', 'Menopausal symptom', 'arthritic symptoms', 'Menstrual bleeding present', 'Pruritus', 'Erythema', 'Redness of skin over lesion'], 'symptoms_diseases': ['Menopausal symptom']}
# Ground Truth:  {'drugs': ['Arthrotec', 'Arthrotec'], 'ades': ['Vaginal Hemorrhage', 'Mastodynia', 'erithema', 'skin is so dry', 'sweating a lot', 'Pruritus', 'Diarrhea', 'Vaginal Hemorrhage', 'Pruritus', 'skin was all red', 'vaginal skin burns', 'cycle was back', 'cuts on my hands'], 'symptoms_diseases': ['Pain']}
# Attempt 3 failed: similarity verification failed
# Max retries reached. Using current result.
#
# Processing post 166/400: DICLOFENAC-SODIUM.4.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["VOLTAREN"],
#   "ades": ["stomach"],
#   "symptoms_diseases": []
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Voltaren'], 'ades': ['Stomach structure'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': ['Voltaren'], 'ades': ['Hard on my stomach'], 'symptoms_diseases': []}
# Attempt 1 failed: completeness verification failed
# Retrying with feedback: Feedback: Check entity accuracy or category assignment.
# Attempt 2: Raw JSON string - ```json
# {
#   "drugs": ["VOLTAREN"],
#   "ades": ["stomach"],
#   "symptoms_diseases": []
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Voltaren'], 'ades': ['Stomach structure'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': ['Voltaren'], 'ades': ['Hard on my stomach'], 'symptoms_diseases': []}
# Attempt 2 failed: completeness verification failed
# Retrying with feedback: Feedback: Check entity accuracy or category assignment.
# Attempt 3: Raw JSON string - ```json
# {
#   "drugs": ["VOLTAREN"],
#   "ades": ["stomach"],
#   "symptoms_diseases": []
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Voltaren'], 'ades': ['Stomach structure'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': ['Voltaren'], 'ades': ['Hard on my stomach'], 'symptoms_diseases': []}
# Attempt 3 failed: completeness verification failed
# Max retries reached. Using current result.
#
# Processing post 167/400: DICLOFENAC-SODIUM.5.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["stomach pains", "excessive drowsiness"],
#   "symptoms_diseases": ["pain in left foot", "pain", "drowsiness"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Stomach ache', 'excessive drowsiness'], 'symptoms_diseases': ['Pain in left foot', 'Pain', 'Drowsiness']}
# Ground Truth:  {'drugs': [], 'ades': ['Stomach ache', 'excessive drowsiness'], 'symptoms_diseases': ['Pain', 'hobbling', 'foot was hurting']}
# ALL CHECKS PASSED!
#
# Processing post 168/400: DICLOFENAC-SODIUM.6.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": [],
#   "symptoms_diseases": ["chronic pain", "trigger point pain"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': [], 'symptoms_diseases': ['Chronic pain', 'trigger point pain']}
# Ground Truth:  {'drugs': ['Neurontin'], 'ades': ['Drowsiness', 'Feeling intoxicated', 'Amnesia'], 'symptoms_diseases': ['trigger point pain', 'Chronic pain']}
# Attempt 1 failed: completeness verification failed
# Retrying with feedback: Feedback: Try extracting more 'drugs' (expected 1, got 0), more 'ades' (expected 3, got 0).
# Attempt 2: Raw JSON string - ```json
# {
#   "drugs": ["drug name not provided"],
#   "ades": ["chronic pain", "trigger point pain", "Neurontin"],
#   "symptoms_diseases": []
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['drug name not provided'], 'ades': ['Chronic pain', 'trigger point pain', 'Neurontin'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': ['Neurontin'], 'ades': ['Drowsiness', 'Feeling intoxicated', 'Amnesia'], 'symptoms_diseases': ['trigger point pain', 'Chronic pain']}
# Attempt 2 failed: completeness verification failed, similarity verification failed
# Retrying with feedback: Feedback: Try extracting more 'symptoms_diseases' (expected 2, got 0).
# Attempt 3: Raw JSON string - ```json
# {
#   "drugs": ["drug name not provided"],
#   "ades": ["chronic pain", "trigger point pain", "Neurontin"],
#   "symptoms_diseases": ["chronic pain", "trigger point pain"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['drug name not provided'], 'ades': ['Chronic pain', 'trigger point pain', 'Neurontin'], 'symptoms_diseases': ['Chronic pain', 'trigger point pain']}
# Ground Truth:  {'drugs': ['Neurontin'], 'ades': ['Drowsiness', 'Feeling intoxicated', 'Amnesia'], 'symptoms_diseases': ['trigger point pain', 'Chronic pain']}
# Attempt 3 failed: completeness verification failed, similarity verification failed
# Max retries reached. Using current result.
#
# Processing post 169/400: DICLOFENAC-SODIUM.7.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["stomach upset", "perforated ulcer", "bleeding", "peritonitis", "septicaemia", "renal failure", "respiratory failure"],
#   "symptoms_diseases": ["gastric ulcer", "arthritis", "post-operative complications", "stoma", "wound", "weight loss"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Upset stomach', 'Perforated ulcer', 'Hemorrhage', 'Peritonitis', 'Puerperal sepsis', 'Kidney Failure', 'Respiratory Failure'], 'symptoms_diseases': ['Gastric ulcer', 'Arthritis', 'History of post-operative complication of surgical procedure', 'Surgical Stoma', 'Traumatic Wound', 'Weight Loss']}
# Ground Truth:  {'drugs': [], 'ades': ['Hemorrhage', 'Upset stomach', 'Perforated ulcer', 'Peritonitis', 'renal and respiratory failure', 'Puerperal sepsis', 'Kidney Failure'], 'symptoms_diseases': ['Arthritis']}
# ALL CHECKS PASSED!
#
# Processing post 170/400: FLECTOR.1.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Flector patch"],
#   "ades": ["puffiness", "pain"],
#   "symptoms_diseases": ["plantar fasciitis", "heel pain", "foot discomfort"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['diclofenac Medicated Patch [Flector]'], 'ades': ['Puffiness of skin', 'Pain'], 'symptoms_diseases': ['Fasciitis, Plantar', 'Heel pain', 'foot discomfort']}
# Ground Truth:  {'drugs': ['diclofenac Medicated Patch [Flector]'], 'ades': [], 'symptoms_diseases': ['Pain', 'Pain', 'pain in my right heel', 'Fasciitis, Plantar', 'Puffiness of skin']}
# Attempt 1 failed: similarity verification failed
# Retrying with feedback: Feedback: Try extracting fewer 'ades' (expected 0, got 2), more 'symptoms_diseases' (expected 5, got 3).
# Attempt 2: Raw JSON string - ```json
# {
#   "drugs": ["Flector patch"],
#   "ades": ["puffiness", "pain"],
#   "symptoms_diseases": ["plantar fasciitis", "heel pain", "foot discomfort"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['diclofenac Medicated Patch [Flector]'], 'ades': ['Puffiness of skin', 'Pain'], 'symptoms_diseases': ['Fasciitis, Plantar', 'Heel pain', 'foot discomfort']}
# Ground Truth:  {'drugs': ['diclofenac Medicated Patch [Flector]'], 'ades': [], 'symptoms_diseases': ['Pain', 'Pain', 'pain in my right heel', 'Fasciitis, Plantar', 'Puffiness of skin']}
# Attempt 2 failed: similarity verification failed
# Retrying with feedback: Feedback: Try extracting fewer 'ades' (expected 0, got 2), more 'symptoms_diseases' (expected 5, got 3).
# Attempt 3: Raw JSON string - ```json
# {
#   "drugs": ["Flector patch"],
#   "ades": ["puffiness", "pain"],
#   "symptoms_diseases": ["plantar fasciitis", "heel pain", "foot discomfort"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['diclofenac Medicated Patch [Flector]'], 'ades': ['Puffiness of skin', 'Pain'], 'symptoms_diseases': ['Fasciitis, Plantar', 'Heel pain', 'foot discomfort']}
# Ground Truth:  {'drugs': ['diclofenac Medicated Patch [Flector]'], 'ades': [], 'symptoms_diseases': ['Pain', 'Pain', 'pain in my right heel', 'Fasciitis, Plantar', 'Puffiness of skin']}
# Attempt 3 failed: similarity verification failed
# Max retries reached. Using current result.
#
# Processing post 171/400: LIPITOR.1.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["muscle pain", "leg cramps", "fatigue", "irritable", "pain in feet", "neuropathy"],
#   "symptoms_diseases": []
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Myalgia', 'Bilateral cramp of muscle of lower limbs', 'Fatigue', 'Irritable Bowel Syndrome', 'Pain in both feet', 'Neuropathy'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': [], 'ades': ['Fatigue', 'Myalgia', 'Bilateral cramp of muscle of lower limbs', 'Irritable Bowel Syndrome', 'Pain in both feet', 'Neuropathy'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 172/400: LIPITOR.10.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Lipitor"],
#   "ades": ["burning", "severe cramping", "tinnitus", "headaches", "cannot get to sleep"],
#   "symptoms_diseases": ["arthritis", "Myocardial Infarction", "stents implanted", "knee surgery", "shoulder surgery", "torn meniscus"]
# }
# ```
# Parsed successfully
# ...
# Ground Truth:  {'drugs': ['cq10', 'saw palmetto extract', 'fish oils'], 'ades': ['Vertigo', 'Amnesia', 'extreme fatigue', 'Fatigue', 'Vertigo', 'Depression - motion', 'excruciatig pain', 'loss of support in all muscels in particular calf and leg', 'Alopecia', 'loss of sex drive', 'hardest on legs', 'partial tempoary loss of sight one eye', 'muscel pain', 'feeling extremely vulnerable'], 'symptoms_diseases': []}
# Attempt 3 failed: completeness verification failed
# Max retries reached. Using current result.
#
# Processing post 392/400: LIPITOR.298.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Lipitor"],
#   "ades": ["Extreme muscle problems", "joint pain", "Terrible mistake", "His liver was functioning at only 50%"],
#   "symptoms_diseases": ["Terrible mistake", "His liver was functioning at only 50%"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Lipitor'], 'ades': ['Extreme muscle problems', 'Arthralgia', 'Terrible mistake', 'His liver was functioning at only 50%'], 'symptoms_diseases': ['Terrible mistake', 'His liver was functioning at only 50%']}
# Ground Truth:  {'drugs': ['Lipitor', 'Lipitor', 'Lipitor'], 'ades': ['Arthralgia', 'liver was functioning at only 50%', 'Extreme muscle problems', 'cholestrol went up dramatically'], 'symptoms_diseases': []}
# Attempt 1 failed: similarity verification failed
# Retrying with feedback: Feedback: Try extracting more 'drugs' (expected 3, got 1), fewer 'symptoms_diseases' (expected 0, got 2).
# Attempt 2: Raw JSON string - ```json
# {
#   "drugs": ["Lipitor"],
#   "ades": ["Extreme muscle problems", "joint pain", "Terrible mistake", "His liver was functioning at only 50%"],
#   "symptoms_diseases": ["His liver was functioning at only 50%"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Lipitor'], 'ades': ['Extreme muscle problems', 'Arthralgia', 'Terrible mistake', 'His liver was functioning at only 50%'], 'symptoms_diseases': ['His liver was functioning at only 50%']}
# Ground Truth:  {'drugs': ['Lipitor', 'Lipitor', 'Lipitor'], 'ades': ['Arthralgia', 'liver was functioning at only 50%', 'Extreme muscle problems', 'cholestrol went up dramatically'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 393/400: LIPITOR.299.ann
# ------------------------------------
# Attempt 1: Raw JSON string - {
#   "drugs": [],
#   "ades": [],
#   "symptoms_diseases": ["cholesterol"]
# }
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': [], 'symptoms_diseases': ['cholesterol']}
# Ground Truth:  {'drugs': [], 'ades': [], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 394/400: LIPITOR.3.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Lipitor", "ibuprofen"],
#   "ades": ["extreme pain in both shoulders", "discomfort in left hand", "swollen fingers", "restricted movement", "hands are warm to touch", "impossible to make a fist"],
#   "symptoms_diseases": ["pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Lipitor', 'ibuprofen'], 'ades': ['extreme pain in both shoulders', 'discomfort in left hand', 'Swelling of finger', 'Limitation of joint movement', 'hands are warm to touch', 'impossible to make a fist'], 'symptoms_diseases': ['Pain', 'Limitation of joint movement', 'Discomfort', 'Swelling', 'Limitation of joint movement', 'hands are warm to touch', 'impossible to make a fist']}
# Ground Truth:  {'drugs': ['Lipitor', 'Lipitor', 'ibruprofen gel', 'Ibruprofen'], 'ades': ['Pain', 'Pain', 'PAROXYSMAL EXTREME PAIN DISORDER', 'extreme pain in neck', 'extreme pain in both shoulders', 'Pain was worse', 'unable to reach the top of my head with my hands', 'fingers are swollen', 'Limitation of joint movement', 'movement is restricted', 'discomfort in my left hand', 'hands are warm to touch', 'movement is restricted and it is impossible to make a fist'], 'symptoms_diseases': []}
# Attempt 1 failed: similarity verification failed
# Retrying with feedback: Feedback: Try extracting more 'drugs' (expected 4, got 2), more 'ades' (expected 13, got 6), fewer 'symptoms_diseases' (expected 0, got 7).
# Attempt 2: Raw JSON string - ```json
# {
#   "drugs": ["Lipitor", "ibuprofen"],
#   "ades": ["extreme pain in both shoulders", "discomfort in left hand", "swollen fingers", "restricted movement", "hands are warm to touch", "impossible to make a fist", "pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist", "pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist", "pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist", "pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist", "pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist", "pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist", "pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist", "pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist", "pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist", "pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist", "pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist", "pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist", "pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist", "pain", "restricted movement", "discomfort
# Attempt 2 failed with error: No JSON object found: line 1 column 1 (char 0)
# Retrying with feedback: JSON parsing error: No JSON object found: line 1 column 1 (char 0). Please ensure the output is valid JSON.
# Attempt 3: Raw JSON string - ```json
# {
#   "drugs": ["Lipitor", "ibuprofen"],
#   "ades": ["extreme pain in both shoulders", "discomfort in left hand", "swollen fingers", "restricted movement", "hands are warm to touch", "impossible to make a fist"],
#   "symptoms_diseases": ["pain", "restricted movement", "discomfort", "swelling", "restricted movement", "hands are warm to touch", "impossible to make a fist"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Lipitor', 'ibuprofen'], 'ades': ['extreme pain in both shoulders', 'discomfort in left hand', 'Swelling of finger', 'Limitation of joint movement', 'hands are warm to touch', 'impossible to make a fist'], 'symptoms_diseases': ['Pain', 'Limitation of joint movement', 'Discomfort', 'Swelling', 'Limitation of joint movement', 'hands are warm to touch', 'impossible to make a fist']}
# Ground Truth:  {'drugs': ['Lipitor', 'Lipitor', 'ibruprofen gel', 'Ibruprofen'], 'ades': ['Pain', 'Pain', 'PAROXYSMAL EXTREME PAIN DISORDER', 'extreme pain in neck', 'extreme pain in both shoulders', 'Pain was worse', 'unable to reach the top of my head with my hands', 'fingers are swollen', 'Limitation of joint movement', 'movement is restricted', 'discomfort in my left hand', 'hands are warm to touch', 'movement is restricted and it is impossible to make a fist'], 'symptoms_diseases': []}
# Attempt 3 failed: similarity verification failed
# Max retries reached. Using current result.
#
# Processing post 395/400: LIPITOR.30.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["Muscle pain in left arm", "weak feeling", "general malaise"],
#   "symptoms_diseases": []
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Muscle pain in left arm', 'Weakness', 'general malaise'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': [], 'ades': ['MUSCLE PAIN IN LEFT ARM', 'GENERAL MALAISE', 'Weakness'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 396/400: LIPITOR.300.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Lipitor"],
#   "ades": ["Severe muscle pain in calves", "felt very unwell", "high temperature", "cholesterol went up almost immediately after stopping Lipitor"],
#   "symptoms_diseases": ["total cholesterol", "HDL", "cholesterol", "marathons", "high temperature", "muscle pain", "cholesterol"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Lipitor'], 'ades': ['Severe muscle pain in calves', 'felt very unwell', 'High temperature of physical object', 'cholesterol went up almost immediately after stopping Lipitor'], 'symptoms_diseases': ['Serum total cholesterol measurement', 'High Density Lipoproteins', 'cholesterol', 'Group marathon therapy', 'High temperature of physical object', 'Myalgia', 'cholesterol']}
# Ground Truth:  {'drugs': ['Lipitor', 'Lipitor'], 'ades': ['Felt very unwell', 'Severe muscle pain in calves', 'Unable to run', 'HDL dropped'], 'symptoms_diseases': []}
# Attempt 1 failed: similarity verification failed
# Retrying with feedback: Feedback: Try extracting more 'drugs' (expected 2, got 1), fewer 'symptoms_diseases' (expected 0, got 7).
# Attempt 2: Raw JSON string - ```json
# {
#   "drugs": ["Lipitor"],
#   "ades": ["Severe muscle pain in calves", "felt very unwell", "high temperature", "cholesterol went up almost immediately after stopping Lipitor"],
#   "symptoms_diseases": ["total cholesterol", "HDL", "cholesterol", "marathons", "high temperature", "muscle pain", "cholesterol"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Lipitor'], 'ades': ['Severe muscle pain in calves', 'felt very unwell', 'High temperature of physical object', 'cholesterol went up almost immediately after stopping Lipitor'], 'symptoms_diseases': ['Serum total cholesterol measurement', 'High Density Lipoproteins', 'cholesterol', 'Group marathon therapy', 'High temperature of physical object', 'Myalgia', 'cholesterol']}
# Ground Truth:  {'drugs': ['Lipitor', 'Lipitor'], 'ades': ['Felt very unwell', 'Severe muscle pain in calves', 'Unable to run', 'HDL dropped'], 'symptoms_diseases': []}
# Attempt 2 failed: similarity verification failed
# Retrying with feedback: Feedback: Try extracting more 'drugs' (expected 2, got 1), fewer 'symptoms_diseases' (expected 0, got 7).
# Attempt 3: Raw JSON string - ```json
# {
#   "drugs": ["Lipitor"],
#   "ades": ["Severe muscle pain in calves", "felt very unwell", "high temperature", "cholesterol went up almost immediately after stopping Lipitor"],
#   "symptoms_diseases": ["total cholesterol", "HDL", "cholesterol", "marathons", "high temperature", "muscle pain", "cholesterol"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Lipitor'], 'ades': ['Severe muscle pain in calves', 'felt very unwell', 'High temperature of physical object', 'cholesterol went up almost immediately after stopping Lipitor'], 'symptoms_diseases': ['Serum total cholesterol measurement', 'High Density Lipoproteins', 'cholesterol', 'Group marathon therapy', 'High temperature of physical object', 'Myalgia', 'cholesterol']}
# Ground Truth:  {'drugs': ['Lipitor', 'Lipitor'], 'ades': ['Felt very unwell', 'Severe muscle pain in calves', 'Unable to run', 'HDL dropped'], 'symptoms_diseases': []}
# Attempt 3 failed: similarity verification failed
# Max retries reached. Using current result.
#
# Processing post 397/400: LIPITOR.301.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["cholestasis"],
#   "symptoms_diseases": ["chest pain", "muscle weakness and spasms", "Rhabdomyolysis", "heart"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Cholestasis'], 'symptoms_diseases': ['Chest Pain', 'muscle weakness and spasms', 'Rhabdomyolysis', 'Heart']}
# Ground Truth:  {'drugs': [], 'ades': ['Chest Pain', 'Muscle Weakness', 'Refractory infantile spasms', 'every 3 hrs drinking water'], 'symptoms_diseases': ['Rhabdomyolosis']}
# Attempt 1 failed: completeness verification failed
# Retrying with feedback: Feedback: Try extracting more 'ades' (expected 4, got 1), fewer 'symptoms_diseases' (expected 1, got 4).
# Attempt 2: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["cholestasis"],
#   "symptoms_diseases": ["Rhabdomyolysis"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Cholestasis'], 'symptoms_diseases': ['Rhabdomyolysis']}
# Ground Truth:  {'drugs': [], 'ades': ['Chest Pain', 'Muscle Weakness', 'Refractory infantile spasms', 'every 3 hrs drinking water'], 'symptoms_diseases': ['Rhabdomyolosis']}
# Attempt 2 failed: completeness verification failed
# Retrying with feedback: Feedback: Try extracting more 'ades' (expected 4, got 1).
# Attempt 3: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["cholestasis"],
#   "symptoms_diseases": ["Rhabdomyolysis"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['Cholestasis'], 'symptoms_diseases': ['Rhabdomyolysis']}
# Ground Truth:  {'drugs': [], 'ades': ['Chest Pain', 'Muscle Weakness', 'Refractory infantile spasms', 'every 3 hrs drinking water'], 'symptoms_diseases': ['Rhabdomyolosis']}
# Attempt 3 failed: completeness verification failed
# Max retries reached. Using current result.
#
# Processing post 398/400: LIPITOR.302.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Lipitor"],
#   "ades": ["Severe muscle and joint pain", "Pain subsided", "Weight gain"],
#   "symptoms_diseases": ["Severe muscle and joint pain", "Heart attack", "Weight gain"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Lipitor'], 'ades': ['Severe muscle and joint pain', 'Pain subsided', 'Weight Gain'], 'symptoms_diseases': ['Severe muscle and joint pain', 'Myocardial Infarction', 'Weight Gain']}
# Ground Truth:  {'drugs': ['Lipitor', 'Lipitor', 'Lipitor'], 'ades': ['Arthralgia', 'Pain', 'Pain', 'Weight Gain', 'Severe muscle pain', 'could hardly move'], 'symptoms_diseases': ['Myocardial Infarction']}
# ALL CHECKS PASSED!
#
# Processing post 399/400: LIPITOR.303.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": [],
#   "ades": ["persistent dry skin spots", "leg pains", "small amounts of gas"],
#   "symptoms_diseases": ["dry skin spots", "leg pains", "gas"]
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': [], 'ades': ['persistent dry skin spots', 'Pain in lower limb', 'small amounts of gas'], 'symptoms_diseases': ['dry skin spots', 'Pain in lower limb', 'Gas Dosage Form']}
# Ground Truth:  {'drugs': [], 'ades': ['Gas Dosage Form', 'persistent dry skin spots', 'Pain in lower limb'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
#
# Processing post 400/400: LIPITOR.304.ann
# ------------------------------------
# Attempt 1: Raw JSON string - ```json
# {
#   "drugs": ["Lipitor", "Red Yeast Rice"],
#   "ades": ["severe muscle pains", "cramps", "lightheadedness", "depression", "short term memory problems"],
#   "symptoms_diseases": []
# }
# ```
# Parsed successfully
# Extracted:  {'drugs': ['Lipitor', 'red yeast rice'], 'ades': ['severe muscle pains', 'Heat Cramps', 'Lightheadedness', 'Depression - motion', 'Short-term memory within normal limits'], 'symptoms_diseases': []}
# Ground Truth:  {'drugs': ['Lipitor', 'Lipitor', 'Lipitor', 'Lipitor', 'red yeast rice'], 'ades': ['Lightheadedness', 'Depression - motion', 'severe muscle pains', 'Heat Cramps', 'Myalgia', 'Heat Cramps', 'Pain', 'Growing pains', 'Severe pain', 'severe cramps', 'Short-term memory within normal limits'], 'symptoms_diseases': []}
# ALL CHECKS PASSED!
# Successfully processed 326 out of 400 posts.
# Success Rate: 81.50%

# %%
for i in range(10):
    print(f"Post {i+1}:")
    print("Ground Truth:")
    print(standardized_annotated_posts[i])
    print("\nExtracted:")
    print(extracted_json_entities[i])
    print("\n" + "-"*50)
# Out:
# Post 1:
# Ground Truth:
# {'file_name': 'ARTHROTEC.1.ann', 'entities': {'drugs': ['Arthrotec'], 'ades': ['gastric problems', 'little blurred vision', 'feel a bit weird', 'bit drowsy'], 'symptoms_diseases': ['Agony', 'Arthritis', 'Growing pains']}}
#
# Extracted:
# {'file_name': 'ARTHROTEC.1.ann', 'entities': {'drugs': ['Arthrotec', 'dextran 75'], 'ades': ['Drowsiness', 'Blurred vision', 'weird feeling'], 'symptoms_diseases': ['Arthritis', 'Agony']}}
#
# --------------------------------------------------
# Post 2:
# Ground Truth:
# {'file_name': 'ARTHROTEC.10.ann', 'entities': {'drugs': [], 'ades': ['Hunger pangs'], 'symptoms_diseases': ['walk up & down steps sideways', 'Hip joint pain']}}
#
# Extracted:
# {'file_name': 'ARTHROTEC.10.ann', 'entities': {'drugs': [], 'ades': [], 'symptoms_diseases': ['Hunger pangs', 'Hip joint pain']}}
#
# --------------------------------------------------
# Post 3:
# Ground Truth:
# {'file_name': 'ARTHROTEC.100.ann', 'entities': {'drugs': [], 'ades': ['Vaginal Hemorrhage', 'Headache', 'Aphthous Stomatitis', 'Stomach ache'], 'symptoms_diseases': ['Pain']}}
#
# Extracted:
# {'file_name': 'ARTHROTEC.100.ann', 'entities': {'drugs': [], 'ades': ['Vaginal Hemorrhage', 'Stomach ache', 'Aphthous Stomatitis', 'Headache', 'Hemorrhage'], 'symptoms_diseases': ['Onset of menstrual cycle', 'Pain']}}
#
# --------------------------------------------------
# Post 4:
# Ground Truth:
# {'file_name': 'ARTHROTEC.101.ann', 'entities': {'drugs': [], 'ades': ['Upset stomach', 'Depression - motion', 'Cramping sensation quality', 'Dyspnea'], 'symptoms_diseases': []}}
#
# Extracted:
# {'file_name': 'ARTHROTEC.101.ann', 'entities': {'drugs': [], 'ades': ['Dyspnea', 'sense of depression', 'Cramping sensation quality', 'Upset stomach'], 'symptoms_diseases': []}}
#
# --------------------------------------------------
# Post 5:
# Ground Truth:
# {'file_name': 'ARTHROTEC.102.ann', 'entities': {'drugs': ['Arthrotec'], 'ades': [], 'symptoms_diseases': ["I can't stand or walk for any lengths of time"]}}
#
# Extracted:
# {'file_name': 'ARTHROTEC.102.ann', 'entities': {'drugs': ['Arthrotec'], 'ades': [], 'symptoms_diseases': ["can't stand or walk for any lengths of time"]}}
#
# --------------------------------------------------
# Post 6:
# Ground Truth:
# {'file_name': 'ARTHROTEC.103.ann', 'entities': {'drugs': ['Arthotec'], 'ades': ['so much pain', 'feel weak and almost fainted', 'Hemorrhage'], 'symptoms_diseases': ['pain and stiffness']}}
#
# Extracted:
# {'file_name': 'ARTHROTEC.103.ann', 'entities': {'drugs': ['Arthrotox'], 'ades': ['bleeding forever', 'pain and stiffness', 'felt weak and almost fainted'], 'symptoms_diseases': ['pain and stiffness']}}
#
# --------------------------------------------------
# Post 7:
# Ground Truth:
# {'file_name': 'ARTHROTEC.104.ann', 'entities': {'drugs': [], 'ades': ['Diarrhea', 'Constipation', 'Fatigue'], 'symptoms_diseases': ['severe osteoarthritis in the knees', 'severe osteoarthritis in the hands', "the heel I couldn't walk on very well", 'Pain']}}
#
# Extracted:
# {'file_name': 'ARTHROTEC.104.ann', 'entities': {'drugs': [], 'ades': ['Diarrhea', 'Constipation', 'Fatigue'], 'symptoms_diseases': ['severe osteoarthritis']}}
#
# --------------------------------------------------
# Post 8:
# Ground Truth:
# {'file_name': 'ARTHROTEC.105.ann', 'entities': {'drugs': ['Arthrotec', 'HA (Hyaluronic Acid)'], 'ades': ['"empty stomach" feeling', 'Loose stool', 'Insomina', 'Swelling of body structure', 'Facial swelling (finding)', 'forgetfulnes and confussion', 'swelling thighs', 'Bilateral swelling of wrist joints', 'Abdomen distended'], 'symptoms_diseases': []}}
#
# Extracted:
# {'file_name': 'ARTHROTEC.105.ann', 'entities': {'drugs': ['Arthrotec'], 'ades': ['Swelling of body structure', 'Facial swelling (finding)', 'Swelling of wrist joint', 'Abdomen distended', 'thigh swelling', 'Sleeplessness', 'Age-associated memory impairment', 'Clouded consciousness', 'Loose stool'], 'symptoms_diseases': ['tight clothes fit', 'empty stomach feeling', 'Loose stool']}}
#
# --------------------------------------------------
# Post 9:
# Ground Truth:
# {'file_name': 'ARTHROTEC.106.ann', 'entities': {'drugs': ['Arthrotec', 'Arthrotec'], 'ades': [], 'symptoms_diseases': ['Arthritis', 'Pain']}}
#
# Extracted:
# {'file_name': 'ARTHROTEC.106.ann', 'entities': {'drugs': ['Arthrotec'], 'ades': [], 'symptoms_diseases': ['Arthritis', 'Knee Replacement Arthroplasty']}}
#
# --------------------------------------------------
# Post 10:
# Ground Truth:
# {'file_name': 'ARTHROTEC.107.ann', 'entities': {'drugs': [], 'ades': ['Rectal hemorrhage', 'felt I might not survive', 'extremely sick'], 'symptoms_diseases': []}}
#
# Extracted:
# {'file_name': 'ARTHROTEC.107.ann', 'entities': {'drugs': [], 'ades': ['extreme rectal bleed', 'Sick Sinus Syndrome', 'Home hospitalization'], 'symptoms_diseases': []}}
#
# --------------------------------------------------
